# %%
import streamlit as st
import pandas as pd
import numpy as np
from datetime import datetime
import os

# %%
df = pd.read_excel("/Users/mateoc/Desktop/Analítica de Datos y Herramientas de IA/Streamllit/sellers.xlsx")
df.head()
# Out:
#   REGION    ID            NAME         LASTNAME  INCOME  SOLD UNITS  \
# 0  NORTE  8725          Arturo  Bustos González   12041         212
# 1  NORTE  4352      Jesús Said      Caro Ibarra   11504         488
# 2  NORTE  5185     Ana Valeria  Cruz Montesinos   10046         429
# 3  NORTE  6918         Miranda      Doring Romo   10266         109
# 4  NORTE  8607  Bruno Guissepe   Garcini García   10431         222
#
#    TOTAL SALES  SALES AVERAGE
# 0         4554       0.069343
# 1         3298       0.050218
# 2         7238       0.110211
# 3         5635       0.085803
# 4         5405       0.082300

# %%
Display the table and filter it by Region.
Display graphs of Units Sold, Total Sales, and Average Sales.
Display data for a specific vendor.
Use containers, buttons, and/or other input and filtering elements, graphs, and any other components you think might be useful.
